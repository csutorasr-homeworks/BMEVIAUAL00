# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
from sklearn import preprocessing
import pylab as plt
from mpl_toolkits.mplot3d import Axes3D
import pickle
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ##### 1. Loading data:

# %% [markdown]
# The stroke statistics are stored in quadruples for each stroke, paired with the predeterined horizontal value.

# %%
stat = pickle.load(open('stat', 'rb'))
pd_stat_per_file = [pd.DataFrame(np.array(file), columns=['Degree', 'H_Dist', 'D_Dist', 'Length', 'Horizontal']) 
                 for file in stat]

np_stat_per_file = np.array([np.array(file) for file in stat])

summerized_stat = []

for file in stat:
    for stroke in file:
        summerized_stat.append(stroke)

# All of the stroke parameter vectors are stored in this variable.
np_stat = np.array(summerized_stat)

data_length = len(np_stat)

for data_frame in pd_stat_per_file:
    print(data_frame.head())
# Out:
#       Degree      H_Dist      D_Dist    Length  Horizontal
# 0  70.204014  124.916667    6.925876  0.508186         0.0
# 1  34.067554  122.906250  136.099238  1.802150         0.0
# 2  72.038094  227.611111   92.824134  2.147402         0.0
# 3  78.323396  145.500000    4.872088  0.613679         0.0
# 4  37.804315   45.500000   18.753902  0.506339         1.0
#     Degree   H_Dist   D_Dist    Length Horizontal
# 0  106.197  382.821  15.3378  0.979135          0
# 1  64.8474  292.844  129.261   1.77307          0
# 2   51.413  184.567  116.328   2.26148          0
# 3  23.7136  5.70833  3.97414   0.61202          1
# 4  95.6023  354.583  4.32749  0.854233          0
#        Degree    H_Dist     D_Dist    Length  Horizontal
# 0   76.028415  193.1875  14.142646  0.564846         0.0
# 1   10.142556   17.2500   5.880144  0.289417         1.0
# 2   77.450204  201.5625  34.418326  0.982743         0.0
# 3  100.146923   61.1500  58.507085  0.557228         0.0
# 4   41.729833   44.3125  37.873035  0.353547         0.0
#     Degree   H_Dist   D_Dist    Length Horizontal
# 0  82.6278  201.083  2.12329  0.734216          0
# 1  71.9369  168.438  8.47745  0.639631          0
# 2  22.6663     23.6  3.46447  0.221677          1
# 3  68.4928     61.5  62.0419   1.04162          0
# 4  71.4288   160.55   53.641   1.29318          0
#     Degree   H_Dist   D_Dist    Length Horizontal
# 0  77.9779    268.6  8.03103   1.75997          0
# 1  26.8968    5.625  4.81844  0.428015          1
# 2  95.5848  196.417  16.9572   1.32411          0
# 3  48.7514  62.0833  68.6166   1.81938          0
# 4  79.1122  204.306  41.1645   2.38173          0
#       Degree      H_Dist     D_Dist    Length  Horizontal
# 0  75.777498  162.333333   4.612911  0.762714         0.0
# 1  40.959704  137.093750  98.826083  1.898746         0.0
# 2  57.616243  163.166667  76.102210  1.745902         0.0
# 3  55.172285  136.022727  49.083434  2.338822         0.0
# 4  28.827053   80.598214  66.904990  4.100955         0.0
#       Degree      H_Dist     D_Dist    Length  Horizontal
# 0  69.893610  180.250000   9.176506  0.793871         0.0
# 1  17.370035  113.060000  67.905241  3.606388         0.0
# 2  41.298810   44.833333  46.324212  1.280651         0.0
# 3  51.623350   46.734375  44.431033  1.721588         0.0
# 4  96.962903   51.600000  33.036763  0.771397         0.0
#     Degree   H_Dist   D_Dist    Length Horizontal
# 0  101.626  148.688  3.07541  0.540121          0
# 1  15.9443   11.875  15.1087  0.386452          1
# 2   42.018  158.776  111.889    2.6414          0
# 3  57.8194  44.6667  46.6281  0.895574          0
# 4  36.8427  54.2024  54.1846   3.15312          0
#       Degree      H_Dist     D_Dist    Length  Horizontal
# 0  79.240903  159.125000  13.248855  0.751809         0.0
# 1  38.306488  108.671875  40.939866  2.661276         0.0
# 2  53.645884   55.418182  44.315710  1.523711         0.0
# 3  64.220072   86.450000  32.329692  1.364288         0.0
# 4  64.694869  116.000000   4.298235  0.564666         0.0
#        Degree      H_Dist      D_Dist    Length  Horizontal
# 0   89.845258  177.250000    5.384421  0.597614         0.0
# 1   51.546377  112.214286  108.532732  1.033372         0.0
# 2   83.524927   52.416667   54.084554  0.725240         0.0
# 3  123.375074  105.714286   42.417319  0.781124         0.0
# 4   49.733993   70.416667   60.548836  0.739211         0.0
#     Degree   H_Dist   D_Dist    Length Horizontal
# 0   77.896  163.875  15.1746  0.494476          0
# 1  37.4383  164.783  207.349   1.75807          0
# 2  140.485    48.05  83.8392  0.804403          0
# 3  71.4738   67.375  72.9176   1.01775          0
# 4   52.114     53.8  48.6204  0.785401          0
#        Degree      H_Dist      D_Dist    Length  Horizontal
# 0   76.948217  152.375000  137.522447  2.842734         0.0
# 1  108.069477   58.600000   41.231430  0.616237         0.0
# 2   51.441723   46.000000   48.777180  0.506135         0.0
# 3   78.083489  129.416667    3.782388  0.525818         0.0
# 4   21.316453   52.421053   49.414530  2.451405         0.0
#       Degree      H_Dist      D_Dist    Length  Horizontal
# 0  42.363624  111.859375  113.688361  1.692838         0.0
# 1  15.175252   63.147727   98.427778  1.805385         0.0
# 2  24.524689   18.166667   32.764833  0.256053         1.0
# 3  14.047530   76.939130   91.677603  2.866132         0.0
# 4  96.751298  194.583333    5.926548  0.421240         0.0
#        Degree      H_Dist      D_Dist    Length  Horizontal
# 0   47.092166  142.928571  122.465589  2.529990         0.0
# 1   18.525079    9.000000    9.233650  0.957433         1.0
# 2  124.730488   96.500000   20.703880  1.058291         0.0
# 3   62.973620   23.875000    6.483711  0.509509         1.0
# 4   63.219133   38.050000   36.475689  1.080032         0.0
#     Degree   H_Dist   D_Dist    Length Horizontal
# 0  85.4176  240.867  5.72164  0.941661          0
# 1  22.3569  169.719  77.6149   3.61377          0
# 2  52.4312  127.446  69.8795   2.52877          0
# 3  98.9541  141.771  37.0471    1.7424          0
# 4   25.091       48  51.2591   1.93799          0
#     Degree   H_Dist   D_Dist    Length Horizontal
# 0  81.8842  220.375  18.2093   1.15693          0
# 1  67.2511  129.875  17.4794   1.06964          0
# 2  173.547  10.4545  13.7834  0.706254          1
# 3  38.8718  55.8333   54.146   1.60193          0
# 4  127.611  94.9583  47.4973   1.17815          0
#        Degree      H_Dist      D_Dist    Length  Horizontal
# 0   57.659441  129.057692  100.515128  4.468459         0.0
# 1   82.734300  128.571429   77.454888  2.509788         0.0
# 2   96.137687   99.125000    3.054429  0.562149         0.0
# 3  171.979976    1.250000    2.687006  0.047009         0.0
# 4  116.365468  191.687500   17.549324  1.415160         0.0
#     Degree   H_Dist   D_Dist   Length Horizontal
# 0  82.6843   201.65  6.33731  1.67799          0
# 1  38.3011  65.3684  102.028  1.79676          0
# 2  54.4376   87.375  72.4754   1.7097          0
# 3  77.3475     49.5  55.8833  1.42905          0
# 4   130.23       72  36.8926  1.24051          0
#        Degree      H_Dist     D_Dist    Length  Horizontal
# 0   69.252995  221.916667  22.429205  1.305399         0.0
# 1   76.912119  196.650000   4.648512  0.992974         0.0
# 2   53.138009   14.562500   4.378263  0.494426         1.0
# 3   87.731134   38.850000  39.256857  1.061458         0.0
# 4  109.326824   69.375000  10.643316  0.456067         0.0
#     Degree   H_Dist   D_Dist    Length Horizontal
# 0  71.0295   235.45  16.8706   1.73747          0
# 1  3.61946  3.58333  4.46088  0.668786          1
# 2  79.2401   239.52  49.4551   2.02535          0
# 3   77.006  64.6667  11.0868  0.305274          0
# 4  52.0961  64.0417  60.8866   1.80695          0

# %% [markdown]
# ##### 2. Visualizing data:

# %% [markdown]
# Average degree is calculated by taking the avarge of the included angle between every vector defined by each consecutive points and a horizontal line.
# The second parameter is the average of the distance of a stroke's points from the horizontal line that goes through that stroke's first point.
# The third parameter is similar to the previous one, in that measurement is the average distance from a line, altough it is now a line that is defined by the directional vector from the first to the last point.
# Fourth parameter is the stroke's length divided by the average length of the text's strokes.

# %%
fig = plt.figure()
fig.suptitle('Degree - Length', fontsize=10)
fig.add_subplot(2,2,1)
plt.scatter(np_stat_per_file[0][:,0], np_stat_per_file[0][:,3], c=np_stat_per_file[0][:,4])
plt.xlabel('Degree', fontsize=10)
plt.ylabel('Length', fontsize=10)
fig.add_subplot(2,2,2)
plt.scatter(np_stat_per_file[1][:,0], np_stat_per_file[1][:,3], c=np_stat_per_file[1][:,4])
plt.xlabel('Degree', fontsize=10)
plt.ylabel('Length', fontsize=10)
fig.add_subplot(2,2,3)
plt.scatter(np_stat_per_file[2][:,0], np_stat_per_file[2][:,3], c=np_stat_per_file[2][:,4])
plt.xlabel('Degree', fontsize=10)
plt.ylabel('Length', fontsize=10)
fig.add_subplot(2,2,4)
plt.scatter(np_stat_per_file[3][:,0], np_stat_per_file[3][:,3], c=np_stat_per_file[3][:,4])
plt.xlabel('Degree', fontsize=10)
plt.ylabel('Length', fontsize=10)

# %%
fig = plt.figure()
fig.suptitle('H_Distance - Length', fontsize=10)
fig.add_subplot(2,2,1)
plt.scatter(np_stat_per_file[0][:,1], np_stat_per_file[0][:,3], c=np_stat_per_file[0][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('Length', fontsize=10)
fig.add_subplot(2,2,2)
plt.scatter(np_stat_per_file[1][:,1], np_stat_per_file[1][:,3], c=np_stat_per_file[1][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('Length', fontsize=10)
fig.add_subplot(2,2,3)
plt.scatter(np_stat_per_file[2][:,1], np_stat_per_file[2][:,3], c=np_stat_per_file[2][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('Length', fontsize=10)
fig.add_subplot(2,2,4)
plt.scatter(np_stat_per_file[3][:,1], np_stat_per_file[3][:,3], c=np_stat_per_file[3][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('Length', fontsize=10)

# %%
fig = plt.figure()
fig.suptitle('H_Distance - D_Distance', fontsize=10)
fig.add_subplot(2,2,1)
plt.scatter(np_stat_per_file[0][:,1], np_stat_per_file[0][:,2], c=np_stat_per_file[0][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('D_Distance', fontsize=10)
fig.add_subplot(2,2,2)
plt.scatter(np_stat_per_file[1][:,1], np_stat_per_file[1][:,2], c=np_stat_per_file[1][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('D_Distance', fontsize=10)
fig.add_subplot(2,2,3)
plt.scatter(np_stat_per_file[2][:,1], np_stat_per_file[2][:,2], c=np_stat_per_file[2][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('D_Distance', fontsize=10)
fig.add_subplot(2,2,4)
plt.scatter(np_stat_per_file[3][:,1], np_stat_per_file[3][:,2], c=np_stat_per_file[3][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('D_Distance', fontsize=10)

# %%
fig = plt.figure()
fig.suptitle('H_Distance - Degree', fontsize=10)
fig.add_subplot(2,2,1)
plt.scatter(np_stat_per_file[0][:,1], np_stat_per_file[0][:,0], c=np_stat_per_file[0][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('Degree', fontsize=10)
fig.add_subplot(2,2,2)
plt.scatter(np_stat_per_file[1][:,1], np_stat_per_file[1][:,0], c=np_stat_per_file[1][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('Degree', fontsize=10)
fig.add_subplot(2,2,3)
plt.scatter(np_stat_per_file[2][:,1], np_stat_per_file[2][:,0], c=np_stat_per_file[2][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('Degree', fontsize=10)
fig.add_subplot(2,2,4)
plt.scatter(np_stat_per_file[3][:,1], np_stat_per_file[3][:,0], c=np_stat_per_file[3][:,4])
plt.xlabel('H_Distance', fontsize=10)
plt.ylabel('Degree', fontsize=10)

# %%
fig = plt.figure()
fig.suptitle('H_Distance - Degree - D_distance', fontsize=20)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(np_stat_per_file[0][:,1], np_stat_per_file[0][:,0],
                                              np_stat_per_file[0][:,2], c=np_stat_per_file[0][:,4])
ax.set_xlabel('H_Distance', fontsize=16)
ax.set_ylabel('Degree', fontsize=16)
ax.set_zlabel('D_distance', fontsize=16)

# %% [markdown]
# ##### 3. Spitting data:

# %% [markdown]
# First step is to separate the stroke data vector into 5 columns.

# %%
avg_degree = np_stat[:,0]
h_distance = np_stat[:,1]
d_distance = np_stat[:,2]
length = np_stat[:,3]
h_value = np_stat[:,4]

# %% [markdown]
# Each column is divided into 3 parts, train, validation and test data.

# %%
train_split = 0.7
valid_split = 0.2
test_split = 0.1

train_avg_degree = np.array(avg_degree[:data_length-int(data_length*0.1)-int(data_length*0.2)], dtype='float').reshape(-1, 1)
train_h_distance = np.array(h_distance[:data_length-int(data_length*0.1)-int(data_length*0.2)], dtype='float').reshape(-1, 1)
train_d_distance = np.array(d_distance[:data_length-int(data_length*0.1)-int(data_length*0.2)], dtype='float').reshape(-1, 1)
train_length = np.array(length[:data_length-int(data_length*0.1)-int(data_length*0.2)], dtype='float').reshape(-1, 1)
train_h_value = np.array(h_value[:data_length-int(data_length*0.1)-int(data_length*0.2)], dtype='float').reshape(-1, 1)

valid_avg_degree = np.array(avg_degree[data_length-int(data_length*0.1)-int(data_length*0.2):data_length-int(data_length*0.1)], dtype='float').reshape(-1, 1)
valid_h_distance = np.array(h_distance[data_length-int(data_length*0.1)-int(data_length*0.2):data_length-int(data_length*0.1)], dtype='float').reshape(-1, 1)
valid_d_distance = np.array(d_distance[data_length-int(data_length*0.1)-int(data_length*0.2):data_length-int(data_length*0.1)], dtype='float').reshape(-1, 1)
valid_length = np.array(length[data_length-int(data_length*0.1)-int(data_length*0.2):data_length-int(data_length*0.1)], dtype='float').reshape(-1, 1)
valid_h_value = np.array(h_value[data_length-int(data_length*0.1)-int(data_length*0.2):data_length-int(data_length*0.1)], dtype='float').reshape(-1, 1)

test_avg_degree = np.array(avg_degree[data_length-int(data_length*0.1):], dtype='float').reshape(-1, 1)
test_h_distance = np.array(h_distance[data_length-int(data_length*0.1):], dtype='float').reshape(-1, 1)
test_d_distance = np.array(d_distance[data_length-int(data_length*0.1):], dtype='float').reshape(-1, 1)
test_length = np.array(length[data_length-int(data_length*0.1):], dtype='float').reshape(-1, 1)
test_h_value = np.array(h_value[data_length-int(data_length*0.1):], dtype='float').reshape(-1, 1)

# %% [markdown]
# Standarization of each parameter.

# %%
degree_scaler = preprocessing.StandardScaler().fit(train_avg_degree)
h_distance_scaler = preprocessing.StandardScaler().fit(train_h_distance)
d_distance_scaler = preprocessing.StandardScaler().fit(train_d_distance)
length_scaler = preprocessing.StandardScaler().fit(train_length)

train_avg_degree = degree_scaler.transform(train_avg_degree)
train_h_distance = h_distance_scaler.transform(train_h_distance)
train_d_distance = d_distance_scaler.transform(train_d_distance)
train_length = length_scaler.transform(train_length)

valid_avg_degree = degree_scaler.transform(valid_avg_degree)
valid_h_distance = h_distance_scaler.transform(valid_h_distance)
valid_d_distance = d_distance_scaler.transform(valid_d_distance)
valid_length = length_scaler.transform(valid_length)

test_avg_degree = degree_scaler.transform(test_avg_degree)
test_h_distance = h_distance_scaler.transform(test_h_distance)
test_d_distance = d_distance_scaler.transform(test_d_distance)
test_length = length_scaler.transform(test_length)

# %% [markdown]
# Reshaping the four parameter arrays into a single matrix.

# %%
temp_array = np.array([train_avg_degree, train_h_distance, train_d_distance, train_length])
std_train_input = []
for i in range(temp_array.shape[1]):
    std_train_input.append(temp_array[:,i])

temp_array = np.array([valid_avg_degree, valid_h_distance, valid_d_distance, valid_length])
std_valid_input = []
for i in range(temp_array.shape[1]):
    std_valid_input.append(temp_array[:,i])

temp_array = np.array([test_avg_degree, test_h_distance, test_d_distance, test_length])
std_test_input = []
for i in range(temp_array.shape[1]):
    std_test_input.append(temp_array[:,i])
    
std_train_input = np.array(std_train_input).reshape(np.array(std_train_input).shape[0], np.array(std_train_input).shape[1])
std_valid_input = np.array(std_valid_input).reshape(np.array(std_valid_input).shape[0], np.array(std_valid_input).shape[1])
std_test_input = np.array(std_test_input).reshape(np.array(std_test_input).shape[0], np.array(std_test_input).shape[1])

pd.DataFrame(std_valid_input, columns=['Degree', 'H_Dist', 'D_Dist', 'Length'])
# Out:
#        Degree    H_Dist    D_Dist    Length
# 0    0.973195  1.565696  0.830618  0.412334
# 1    1.011067 -0.123480  0.581926 -0.180973
# 2   -0.956085 -0.025428  1.325921 -0.165408
# 3   -0.771256 -0.162701  0.618017  0.002390
# 4    0.080085 -0.117435  0.448124 -0.253111
# 5   -0.268375  0.439462  0.473577  0.185973
# 6   -1.333850  0.330948  1.397281  4.361579
# 7   -1.882630 -1.181506 -1.053851 -0.584032
# 8   -0.005901  0.059817  1.458153  1.618513
# 9    0.102216  0.003287  1.123284  0.698552
# 10   1.118810  1.088361  0.988980  0.564039
# 11   0.348197  2.612944 -1.019082 -0.292766
# 12  -1.076978 -1.193512 -1.064964 -0.761719
# 13  -0.451626  0.224728  1.345685  2.035137
# 14  -1.485926 -1.046101 -1.032933 -0.559532
# 15   0.550715  3.123436 -0.820347 -0.157550
# 16   0.032766  1.512585 -1.024866 -0.324773
# 17  -1.855608 -1.193512 -1.014029 -0.646037
# 18   1.105036  0.456193  1.260371 -0.208709
# 19   2.127094 -1.165942 -0.996009 -0.896570
# 20  -0.535062  0.416030  0.037251  0.144994
# 21   0.117550  0.638523  0.705995  0.714717
# 22   0.297914 -1.214190 -0.959870 -0.896396
# 23  -0.321283  0.618446  0.474991  0.082254
# 24   0.058944  1.928656  0.641842  0.665990
# 25   0.177363  1.548900 -0.302101  1.236146
# 26  -0.904967  0.241413  1.249874  1.069003
# 27  -0.613236  1.939810  3.409838  1.500512
# 28   0.396351  2.164707 -0.884912 -0.330199
# 29   2.090784 -1.083454 -0.936844 -0.873581
# ..        ...       ...       ...       ...
# 715 -0.641405 -0.190093 -0.710194 -0.406191
# 716  1.565780  1.103257 -0.991157 -0.037116
# 717  1.103789 -0.997853 -1.061263 -0.851477
# 718  0.244827  0.933612 -0.972154 -0.160964
# 719 -0.432933  0.465142  0.991085  0.587753
# 720 -0.081034 -0.310712  0.625949  0.137816
# 721  0.689221 -1.169833 -1.072277 -0.864697
# 722  0.063474  1.007651  2.245553  0.654689
# 723  0.064232 -0.964391 -1.019423 -0.614871
# 724  0.441738 -0.175307  0.381818  0.875259
# 725 -0.444542 -0.697917 -0.006647  0.123029
# 726 -0.349722 -0.205048  0.064799  0.010011
# 727 -0.350791 -0.482519 -0.216961  0.085473
# 728 -0.923950 -0.587747 -0.027367  0.062443
# 729 -1.421722 -0.793578 -0.253680  1.027200
# 730  1.543557 -0.604089 -0.913789 -0.614098
# 731  0.014035 -1.018086 -0.795196 -0.802361
# 732  1.928181 -0.468996 -0.270504 -0.167528
# 733 -0.051543 -0.289701 -1.002555 -0.622477
# 734  0.724488 -0.511485 -0.976794 -0.706720
# 735 -0.852518 -0.847196 -0.346096 -0.291526
# 736 -0.037923 -0.518489 -0.409614 -0.040457
# 737  0.565709  0.703268 -1.022693 -0.186847
# 738 -1.649829 -0.833322 -0.202222  0.287307
# 739 -0.953493 -0.470241 -0.149534  0.112481
# 740  1.126645  0.150365  0.135185  0.636926
# 741  0.142231  0.620780  0.249281  0.291558
# 742  1.871316 -0.349466 -0.053142 -0.098412
# 743 -0.196208  0.041807  0.353192  0.992159
# 744  1.038170 -0.733269 -0.125464 -0.332756
#
# [745 rows x 4 columns]

# %% [markdown]
# ## Building model

# %% [markdown]
# The model is a fully connected network, it has 4 input features for the 4 stroke parameters. There is one hidden layer, with 10 neurons, and a 0.5 dropout. It uses tanh activation in the hidden and output layer as well.

# %%
model = Sequential()
model.add(Dense(input_dim=4, units=10, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='linear'))

# %% [markdown]
# There are 3 callback functions in the model, early stopping, model checkpoint and learning rate reduction.

# %%
from keras.callbacks import EarlyStopping
patience = 50
early_stopping = EarlyStopping(patience=patience, verbose=1)

from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath='weights.hdf5', save_best_only=True, verbose=1)

from keras.callbacks import ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=10e-5)

# %% [markdown]
# Training phase.

# %%
sgd = SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mse', optimizer=sgd)
history = model.fit(std_train_input, train_h_value ,epochs=1000000, batch_size=20,
                    validation_data=(std_valid_input,valid_h_value),
                   callbacks=[early_stopping, checkpointer, reduce_lr])
# Out:
# Train on 2611 samples, validate on 745 samples
# Epoch 1/1000000
# Epoch 00000: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0932 - val_loss: 0.1109
# Epoch 2/1000000
# Epoch 00001: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0722 - val_loss: 0.0690
# Epoch 3/1000000
# Epoch 00002: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0676 - val_loss: 0.0704
# Epoch 4/1000000
# Epoch 00003: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0659 - val_loss: 0.0672
# Epoch 5/1000000
# Epoch 00004: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0659 - val_loss: 0.0747
# Epoch 6/1000000
# Epoch 00005: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0611 - val_loss: 0.0698
# Epoch 7/1000000
# Epoch 00006: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0619 - val_loss: 0.0708
# Epoch 8/1000000
# Epoch 00007: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0622 - val_loss: 0.0667
# Epoch 9/1000000
# Epoch 00008: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0575 - val_loss: 0.0791
# Epoch 10/1000000
# Epoch 00009: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0565 - val_loss: 0.0577
# Epoch 11/1000000
# Epoch 00010: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0566 - val_loss: 0.0763
# Epoch 12/1000000
# Epoch 00011: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0565 - val_loss: 0.0591
# Epoch 13/1000000
# Epoch 00012: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0553 - val_loss: 0.0648
# Epoch 14/1000000
# Epoch 00013: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0558 - val_loss: 0.0625
# Epoch 15/1000000
# Epoch 00014: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0570 - val_loss: 0.0554
# Epoch 16/1000000
# Epoch 00015: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0555 - val_loss: 0.0566
# Epoch 17/1000000
# Epoch 00016: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0538 - val_loss: 0.0593
# Epoch 18/1000000
# Epoch 00017: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0528 - val_loss: 0.0563
# Epoch 19/1000000
# Epoch 00018: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0504 - val_loss: 0.0556
# Epoch 20/1000000
# Epoch 00019: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0533 - val_loss: 0.0612
# Epoch 21/1000000
# Epoch 00020: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0513 - val_loss: 0.0543
# Epoch 22/1000000
# Epoch 00021: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0505 - val_loss: 0.0556
# Epoch 23/1000000
# Epoch 00022: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0511 - val_loss: 0.0521
# Epoch 24/1000000
# Epoch 00023: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0526 - val_loss: 0.0573
# Epoch 25/1000000
# Epoch 00024: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0511 - val_loss: 0.0555
# Epoch 26/1000000
# Epoch 00025: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0513 - val_loss: 0.0503
# Epoch 27/1000000
# Epoch 00026: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0467 - val_loss: 0.0529
# Epoch 28/1000000
# Epoch 00027: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0510 - val_loss: 0.0527
# Epoch 29/1000000
# Epoch 00028: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0491 - val_loss: 0.0534
# Epoch 30/1000000
# Epoch 00029: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0483 - val_loss: 0.0510
# Epoch 31/1000000
# Epoch 00030: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0487 - val_loss: 0.0608
# Epoch 32/1000000
# Epoch 00031: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0502 - val_loss: 0.0510
# Epoch 33/1000000
# Epoch 00032: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0485 - val_loss: 0.0501
# Epoch 34/1000000
# Epoch 00033: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0470 - val_loss: 0.0513
# Epoch 35/1000000
# Epoch 00034: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0471 - val_loss: 0.0506
# Epoch 36/1000000
# Epoch 00035: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0453 - val_loss: 0.0492
# Epoch 37/1000000
# Epoch 00036: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0480 - val_loss: 0.0553
# Epoch 38/1000000
# Epoch 00037: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0450 - val_loss: 0.0528
# Epoch 39/1000000
# Epoch 00038: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0477 - val_loss: 0.0505
# Epoch 40/1000000
# Epoch 00039: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0491 - val_loss: 0.0516
# Epoch 41/1000000
# Epoch 00040: val_loss improved from 0.04913 to 0.04904, saving model to weights.hdf5
# 2611/2611 [==============================] - 0s - loss: 0.0446 - val_loss: 0.0490
# Epoch 42/1000000
# Epoch 00041: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0465 - val_loss: 0.0503
# Epoch 43/1000000
# Epoch 00042: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0454 - val_loss: 0.0493
# Epoch 44/1000000
# Epoch 00043: val_loss improved from 0.04904 to 0.04824, saving model to weights.hdf5
# 2611/2611 [==============================] - 0s - loss: 0.0484 - val_loss: 0.0482
# Epoch 45/1000000
# Epoch 00044: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0477 - val_loss: 0.0498
# Epoch 46/1000000
# Epoch 00045: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0463 - val_loss: 0.0502
# Epoch 47/1000000
# Epoch 00046: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0497 - val_loss: 0.0518
# Epoch 48/1000000
# Epoch 00047: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0466 - val_loss: 0.0551
# Epoch 49/1000000
# Epoch 00048: val_loss improved from 0.04824 to 0.04779, saving model to weights.hdf5
# 2611/2611 [==============================] - 0s - loss: 0.0464 - val_loss: 0.0478
# Epoch 50/1000000
# Epoch 00049: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0469 - val_loss: 0.0493
# Epoch 51/1000000
# Epoch 00050: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0454 - val_loss: 0.0483
# Epoch 52/1000000
# Epoch 00051: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0449 - val_loss: 0.0497
# Epoch 53/1000000
# Epoch 00052: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0491 - val_loss: 0.0502
# Epoch 54/1000000
# Epoch 00053: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0470 - val_loss: 0.0488
# Epoch 55/1000000
# Epoch 00054: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0471 - val_loss: 0.0497
# Epoch 56/1000000
# Epoch 00055: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0513 - val_loss: 0.0499
# Epoch 57/1000000
# Epoch 00056: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0468 - val_loss: 0.0506
# Epoch 58/1000000
# Epoch 00057: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0467 - val_loss: 0.0493
# Epoch 59/1000000
# Epoch 00058: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0462 - val_loss: 0.0489
# Epoch 60/1000000
# Epoch 00059: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0445 - val_loss: 0.0488
# Epoch 61/1000000
# Epoch 00060: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0480 - val_loss: 0.0490
# Epoch 62/1000000
# Epoch 00061: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0482 - val_loss: 0.0494
# Epoch 63/1000000
# Epoch 00062: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0460 - val_loss: 0.0495
# Epoch 64/1000000
# Epoch 00063: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0467 - val_loss: 0.0494
# Epoch 65/1000000
# Epoch 00064: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0474 - val_loss: 0.0497
# Epoch 66/1000000
# Epoch 00065: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0460 - val_loss: 0.0496
# Epoch 67/1000000
# Epoch 00066: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0473 - val_loss: 0.0496
# Epoch 68/1000000
# Epoch 00067: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0476 - val_loss: 0.0496
# Epoch 69/1000000
# Epoch 00068: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0467 - val_loss: 0.0496
# Epoch 70/1000000
# Epoch 00069: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0479 - val_loss: 0.0497
# Epoch 71/1000000
# Epoch 00070: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0467 - val_loss: 0.0496
# Epoch 72/1000000
# Epoch 00071: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0462 - val_loss: 0.0496
# Epoch 73/1000000
# Epoch 00072: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0442 - val_loss: 0.0497
# Epoch 74/1000000
# Epoch 00073: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0430 - val_loss: 0.0497
# Epoch 75/1000000
# Epoch 00074: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0427 - val_loss: 0.0496
# Epoch 76/1000000
# Epoch 00075: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0464 - val_loss: 0.0496
# Epoch 77/1000000
# Epoch 00076: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0472 - val_loss: 0.0496
# Epoch 78/1000000
# Epoch 00077: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0458 - val_loss: 0.0496
# Epoch 79/1000000
# Epoch 00078: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0479 - val_loss: 0.0497
# Epoch 80/1000000
# Epoch 00079: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0451 - val_loss: 0.0497
# Epoch 81/1000000
# Epoch 00080: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0455 - val_loss: 0.0497
# Epoch 82/1000000
# Epoch 00081: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0455 - val_loss: 0.0497
# Epoch 83/1000000
# Epoch 00082: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0445 - val_loss: 0.0497
# Epoch 84/1000000
# Epoch 00083: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0449 - val_loss: 0.0497
# Epoch 85/1000000
# Epoch 00084: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0480 - val_loss: 0.0496
# Epoch 86/1000000
# Epoch 00085: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0440 - val_loss: 0.0497
# Epoch 87/1000000
# Epoch 00086: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0469 - val_loss: 0.0497
# Epoch 88/1000000
# Epoch 00087: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0464 - val_loss: 0.0497
# Epoch 89/1000000
# Epoch 00088: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0479 - val_loss: 0.0496
# Epoch 90/1000000
# Epoch 00089: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0467 - val_loss: 0.0497
# Epoch 91/1000000
# Epoch 00090: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0469 - val_loss: 0.0496
# Epoch 92/1000000
# Epoch 00091: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0477 - val_loss: 0.0497
# Epoch 93/1000000
# Epoch 00092: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0460 - val_loss: 0.0497
# Epoch 94/1000000
# Epoch 00093: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0456 - val_loss: 0.0496
# Epoch 95/1000000
# Epoch 00094: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0457 - val_loss: 0.0496
# Epoch 96/1000000
# Epoch 00095: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0451 - val_loss: 0.0497
# Epoch 97/1000000
# Epoch 00096: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0464 - val_loss: 0.0496
# Epoch 98/1000000
# Epoch 00097: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0456 - val_loss: 0.0496
# Epoch 99/1000000
# Epoch 00098: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0454 - val_loss: 0.0496
# Epoch 100/1000000
# Epoch 00099: val_loss did not improve
# 2611/2611 [==============================] - 0s - loss: 0.0468 - val_loss: 0.0496
# Epoch 00099: early stopping

# %% [markdown]
# Visualizing prediciton data.

# %%
preds = model.predict(std_test_input)

outputs= [1 if p > 0.5 else 0 for p in preds]

fig = plt.figure()
fig.suptitle('H_Distance - Degree - D_distance', fontsize=20)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(std_test_input[:,1], std_test_input[:,0],
                                              std_test_input[:,2], c=outputs)
ax.set_xlabel('H_Distance', fontsize=16)
ax.set_ylabel('Degree', fontsize=16)
ax.set_zlabel('D_distance', fontsize=16)

# %% [markdown]
# Saving model.

# %%
from keras.models import load_model

model.save('right_left.h5')
